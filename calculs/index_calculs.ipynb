# %% [markdown]
# # Calculs Markdown Index
#
# This notebook provides quick links to the markdown documentation in the `calculs` folder.
#
# - [fork_readme.md](fork_readme.md)
# - [fork_readme_fr.md](fork_readme_fr.md)
# - [piston_readme.md](piston_readme.md)
# - [piston_readme_fr.md](piston_readme_fr.md)
#
# and Jupyter Notebooks:
#
# - [Main-piston-tet4.ipynb](piston/Main-piston-tet4.ipynb)
# - [Main-plate-hole-tri3.ipynb](plate-hole/Main-plate-hole-tri3.ipynb)
